# %%
#
# Obtaining data from Twitter using the 'tweepy' package. In order to 
# obtain an API key, you will first need to create a (free) Twitter 
# account. Then go here: https://apps.twitter.com/app/new to create a new 
# 'application'. 
#

import tweepy
import numpy as np

# Replace with your authentication credentials.
consumer_key = '5NMi2BMsEUxt0fGHrbq6i45HB'
consumer_secret = 'YxPTqbw7dROQOI4hnMZ0Fmf3sizBqohZYHJBZfqG3beEBmJ91P'
access_token = '1473429421-qVq1qhqGAAWX30qKa9DZdL3nRMNSkLHtnlGRVoj'
access_token_secret = 'SNt03h6g95RMG1EwdJji8sUzEB4jWk9J0VDTPQg7WOa3f'

# Establish connection to Twitter API.
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8a7e99499563> in <module>()
#       6 #
#       7
# ----> 8 import tweepy
#       9 import numpy as np
#      10
#
# ModuleNotFoundError: No module named 'tweepy'

# %%
# Our first data request: retrieve the most recent tweets from home page.
# Returns the 20 most recent tweets
public_tweets = api.home_timeline()
# add in the line below
# print(type(public_tweets[0]))
for tweet in public_tweets:
    print(tweet.text)
# Out:
# RT @CraigslistTrolI: They offered them a ride 😂😂😂 https://t.co/prPD8CfDQQ
# Us @kattm_ https://t.co/sJuP5Rb64z
# Y'all need to get on them BBQ plates https://t.co/g2rHf3yxw2
# RT @RayB_nine5: Late nights, early mornings, it's gonna pay off one day.
# Join @TAMUGLBTRC on March 3 and see @realleadelaria live in Aggieland! Information &amp; free tickets:… https://t.co/h6CTybaXTX
# Very Important Maps of US History https://t.co/sCZIRfmzfn https://t.co/WK370omqUm
# She finally woke up y'all !!
# Does no one wanna buy one :((( https://t.co/bKMCpqaBva
# I think for not being a swimmer a 31.5 50 free is alright.
# If this ain't the motto then idk https://t.co/J0LqojY3dW
# RT @ALT_DOJ: The Senators who voted for DeVos whose terms are up in 2018
#
# Flake AZ
# Wicker MS
# Fischer NE
# Heller NV
# Corker TN
# Cruz TX
# Hatch U…
# RT @Sneakkfreakk: Traffic always starts cause 1 dumb driver
# RT @HotNewHipHop: MJ straight up told the Warriors owner: "73 wins don't mean shit"
#
# ...

# %%
# Accessing Donald Trump's Twitter feed.
user = api.get_user('realDonaldTrump')
print(user.screen_name)
print(user.followers_count)
for friend in user.friends():
   print(friend.screen_name)
# Out:
# realDonaldTrump
# 24214487
# Reince
# RealRomaDowney
# Trump
# TrumpGolf
# TiffanyATrump
# IngrahamAngle
# mike_pence
# TeamTrump
# DRUDGE_REPORT
# MrsVanessaTrump
# LaraLeaTrump
# seanhannity
# foxnation
# CLewandowski_
# AnnCoulter
# DiamondandSilk
# KatrinaCampins
# KatrinaPierson
# MichaelCohen212
# foxandfriends

# %%
import json
import time
# To access the timeline I would use API.home_timeline([since_id][, max_id])*
# since_id ='2016-03-01'
max_id ='826588658304217088'
#date_min ='2016-03-01'
#date_max ='2017-01-31'
#recent_tweets = api.user_timeline('realDonaldTrump', count = 20000)
recent_tweets = api.user_timeline('realDonaldTrump', count = 200)
#recent_tweets = api.user_timeline('realDonaldTrump', 
for i in range(len(recent_tweets)):
#https://api.twitter.com/1.1/statuses/user_timeline.json?include_entities=true&inc‌​lude_rts=true&screen_name=realDonaldTrump&since:2016-03-01&until:2017-01-31

# %%
#import json
#import pandas as pd
#import matplotlib.pyplot as plt
#tweets_by_country = tweets[].value_counts()
#fig, ax = plt.subplots()
#ax.tick_params(axis='x', labelsize=15)
#ax.tick_params(axis='y', labelsize=10)
#ax.set_xlabel('Countries', fontsize=15)
#ax.set_ylabel('Number of tweets' , fontsize=15)
#ax.set_title('Top 5 countries', fontsize=15, fontweight='bold')
#tweets_by_country[:5].plot(ax=ax, kind='bar', color='blue')

# %%
#lis = [826596187453153281] ## this is the latest starting tweet id
#826637556787838976
#826596187453153281
#826588658304217088

#for i in range(0, 16): ## iterate through all tweets
## tweet extract method with the last list item as the max_id
    #user_timeline = api.user_timeline(screen_name="realDonaldTrump", count=200, include_retweets=False, max_id=lis[-1])
    #time.sleep(300) ## 5 minute rest between api calls

    #for tweet in user_timeline:
        #print (tweet) ## print the tweet
        #lis.append(tweet['id']) ## append tweet id's

# %%
#for i in range(0, 16): ## iterate through 16 times to get max No. of tweets
tweet_dates = []
tweet_years = []
tweet_months = []
tweet_days = []

recent_tweets = api.user_timeline(screen_name="realDonaldTrump",count=200)
for tweet in recent_tweets:
    tca = tweet.created_at
    tweet_dates.append(tca)
    tweet_years.append(tca.year)
    tweet_months.append(tca.month)
    tweet_days.append(tca.day)
    
#for i in range(len(recent_tweets)):
    #print(recent_tweets[i].created_at)

day_num = (np.asarray(tweet_years, dtype=np.float64) - 2000) + np.asarray(tweet_days, dtype = np.float64) / 365
print(day_num)

#print(tca)
#print(recent_tweets[0])
#print(recent_tweets.created_at)
#print(tweet_dates)
#print(tweet_dates[0].year)
#print(tweet_dates[0].month)
#print(tweet_dates[0].day)
# Out:
# [ 17.02465753  17.02191781  17.02191781  17.02191781  17.02191781
#   17.02191781  17.02191781  17.02191781  17.02191781  17.02191781
#   17.02191781  17.02191781  17.01917808  17.01917808  17.01917808
#   17.01917808  17.01643836  17.01643836  17.01643836  17.01643836
#   17.01643836  17.01369863  17.01369863  17.01369863  17.01369863
#   17.01369863  17.0109589   17.0109589   17.0109589   17.0109589
#   17.0109589   17.0109589   17.0109589   17.0109589   17.0109589
#   17.00821918  17.00821918  17.00821918  17.00821918  17.00821918
#   17.00821918  17.00821918  17.00547945  17.00547945  17.00547945
#   17.00547945  17.00547945  17.00547945  17.00547945  17.00547945
#   17.00273973  17.00273973  17.00273973  17.00273973  17.08493151
#   17.08493151  17.08493151  17.08219178  17.08219178  17.08219178
#   17.08219178  17.08219178  17.08219178  17.08219178  17.07945205
#   17.07945205  17.07945205  17.07945205  17.07945205  17.07945205
# ...

# %%
import matplotlib.pyplot as plt
#[2016-03-01, 2017-31-01,0,24:00:00]
plt.axis([17.00273973, 17.08219178, 0, 4])
#plt.ax
#plt.axis([2017-02-08, 2017-01-08,0,24:00:00])
#plt.axis([2016.1167, 2017.083, 0, 24:00:00]) # = the x-axis range and then the y-axis range
#plt.ylabel('tweets per day')
plt.show()

# %%
#tweet1 = recent_tweets[0].copy()

#for string in tweet1.split(""):
    #if string == "'created_at':#
        #previous_string = string

# %%
if __name__ == '__main__':
    #pass in the username of the account you want to download
    get_all_tweets = api.user_timeline('realDonaldTrump')
    print(get_all_tweets)
# Out:
# [Status(is_quote_status=False, retweet_count=8529, in_reply_to_status_id=None, text="'Immigration Ban Is One Of Trump's Most Popular Orders So Far' https://t.co/wAelwuQ4BE", source='Twitter for iPhone', in_reply_to_user_id=None, in_reply_to_screen_name=None, favorite_count=32144, _json={'is_quote_status': False, 'retweet_count': 8529, 'in_reply_to_status_id': None, 'text': "'Immigration Ban Is One Of Trump's Most Popular Orders So Far' https://t.co/wAelwuQ4BE", 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_user_id': None, 'in_reply_to_screen_name': None, 'favorite_count': 32144, 'user': {'default_profile_image': False, 'time_zone': 'Eastern Time (US & Canada)', 'profile_sidebar_fill_color': 'C5CEC0', 'follow_request_sent': False, 'profile_background_color': '6D5C18', 'profile_text_color': '333333', 'favourites_count': 45, 'id_str': '25073877', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images
# ...

# %%
for i in range(len(get_all_tweets)):
    print(get_all_tweets[i].created_at)
# Out:
# 2017-02-08 19:39:51
# 2017-02-08 19:22:33
# 2017-02-08 17:41:09
# 2017-02-08 15:54:01
# 2017-02-08 15:51:01
# 2017-02-08 15:23:29
# 2017-02-08 13:04:47
# 2017-02-08 12:03:18
# 2017-02-08 01:04:00
# 2017-02-07 16:25:13
# 2017-02-07 12:11:29
# 2017-02-07 02:49:28
# 2017-02-07 02:33:55
# 2017-02-06 23:33:52
# 2017-02-06 16:32:24
# 2017-02-06 12:07:55
# 2017-02-06 12:01:53
# 2017-02-06 03:36:54
# 2017-02-05 22:49:42
# 2017-02-05 20:42:33

# %%
#hist, bin_edges = np.histogram([ 17.02465753, 17.02191781, 17.02191781, 17.02191781, 17.02191781, 17.02191781, 17.02191781,  17.02191781,  17.02191781,  17.02191781,
  17.02191781, 17.02191781, 17.01917808,17.01917808, 17.01917808,
  17.01917808, 17.01643836, 17.01643836, 17.01643836, 17.01643836,
  17.01643836, 17.01369863, 17.01369863, 17.01369863, 17.01369863,
  17.01369863, 17.0109589, 17.0109589, 17.0109589, 17.0109589,
  17.0109589,  17.0109589, 17.0109589, 17.0109589, 17.0109589,
  17.00821918, 17.00821918, 17.00821918, 17.00821918, 17.00821918,
  17.00821918, 17.00821918, 17.00547945, 17.00547945, 17.00547945,
  17.00547945, 17.00547945, 17.00547945, 17.00547945, 17.00547945,
  17.00273973, 17.00273973, 17.00273973, 17.00273973, 17.08493151,
  17.08493151, 17.08493151, 17.08219178, 17.08219178, 17.08219178,
  17.08219178, 17.08219178, 17.08219178, 17.08219178, 17.07945205,
  17.07945205, 17.07945205, 17.07945205, 17.07945205, 17.07945205,
  17.07945205, 17.07671233, 17.07671233, 17.07671233, 17.07671233,
  16.0739726, 16.0739726,   16.07123288,  16.07123288,  16.07123288,
  16.07123288, 16.07123288,  16.07123288,  16.07123288,  16.07123288,
  16.07123288, 16.07123288,  16.06849315,  16.06849315,  16.06849315,
  16.06849315, 16.06849315, 16.06849315,  16.06849315,  16.06849315,
  16.06575342, 16.06575342,  16.06575342,  16.06575342,  16.0630137,
  16.06027397, 16.06027397,  16.06027397,  16.06027397,  16.05753425,
  16.05753425, 16.05753425,  16.05479452,  16.05479452, 16.05479452,
  16.05479452, 16.05479452,  16.05479452,  16.05479452,  16.05479452,
  16.05479452, 16.05479452,  16.05479452,  16.05479452,  16.05479452,
  16.05205479, 16.05205479,  16.05205479,  16.05205479, 16.05205479,
  16.05205479, 16.05205479,  16.05205479,  16.04931507,  16.04931507,
  16.04931507, 16.04931507,  16.04931507,  16.04931507,  16.04931507,
  16.04931507, 16.04657534,  16.04657534,  16.04657534,  16.04657534,
  16.04657534, 16.04657534,  16.04657534,  16.04657534, 16.04657534,
  16.04657534, 16.04657534,  16.04657534,  16.04657534,  16.04383562,
  16.04383562, 16.04383562,  16.04109589,  16.04109589,  16.04109589,
  16.04109589, 16.04109589,  16.04109589,  16.04109589,  16.04109589,
  16.03835616, 16.03835616,  16.03835616,  16.03561644,  16.03561644,
  16.03561644, 16.03561644,  16.03561644, 16.03561644, 16.03561644,
  16.03561644, 16.03287671,  16.03287671,  16.03287671,  16.03287671,
  16.03287671, 16.03287671,  16.03013699,  16.03013699,  16.03013699,
  16.03013699, 16.03013699,  16.03013699, 16.03013699,  16.02739726,
  16.02739726, 16.02739726,  16.02739726,  16.02465753,  16.02465753,
  16.02465753, 16.02465753,  16.02465753,  16.02465753,  16.02465753], bins = range(30))
#print(hist)
#print(bin_edges)
import matplotlib.pyplot as plt
plt.bar(bin_edges[:-1], hist, width = 1)
plt.xlim(min(bin_edges), max(bin_edges))
plt.axis([15.1,19.1,0,180])
#plt.title=("Donald Trump's Tweets")
#plt.ylabel=('Tweets per Year')
#plt.xlabel=('Year')
plt.show()

# %%
import numpy as np    
hist, bin_edges = np.histogram([1, 1, 2, 2, 2, 2, 3], bins = range(5))
import pylab

import matplotlib.pyplot as plt
plt.bar(bin_edges[:-1], hist, width = 1)
plt.xlim(min(bin_edges), max(bin_edges))
plt.axis([0,5,0,4])

#n, bins, patches = ax.hist(measurements, bins=50, range=(graph_minimum, graph_maximum), histtype='bar')
#plt.title()
pylab.ylabel = ('tweets per year')
pylab.xlabel = ('year')
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
xedges = [0, 1, 1.5, 3, 5]
yedges = [0, 2, 3, 4, 6]
x = np.random.normal(3, 1, 100)
y = np.random.normal(1, 1, 100)
H, xedges, yedges = np.histogram2d(y, x, bins=(xedges, yedges))
plt.show()

# %%
import matplotlib.pyplot as plt
#[2016-03-01, 2017-31-01,0,24:00:00]
plt.axis([17.00273973, 17.08219178, 0, 4])
#plt.ax
#plt.axis([2017-02-08, 2017-01-08,0,24:00:00])
#plt.axis([2016.1167, 2017.083, 0, 24:00:00]) # = the x-axis range and then the y-axis range
#plt.ylabel('tweets per day')
plt.show()
